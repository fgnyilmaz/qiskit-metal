# %% [markdown]
# # Introduction

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import numpy as np

import warnings
warnings.filterwarnings('ignore')



# sys.path.insert(0, '../array_components')

# %%
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, open_docs , Headings

# %%
from qiskit_metal.qlibrary.qubits.JJ_Manhattan import jj_manhattan 


from qiskit_metal import draw, Dict
from qiskit_metal.toolbox_metal import math_and_overrides
from qiskit_metal.qlibrary.core import QComponent


from qiskit_metal.qlibrary.tlines.meandered import RouteMeander
from qiskit_metal.qlibrary.tlines.pathfinder import RoutePathfinder
from qiskit_metal.qlibrary.terminations.launchpad_wb_driven import LaunchpadWirebondDriven

# from array_smiley_face import SmileyFace

from junction_array import JunctionArray 
# from array_port_coupler import PortCoupler

# %%
design = designs.DesignPlanar()
gui = MetalGUI(design)

design.overwrite_enabled = True

# %% [markdown]
# # Single array cell render
#
#
# I run the component without naming the gds_cell_name. This gives the error.

# %%
design.delete_all_components()

options=Dict(
    pos_x='-00um',
    pos_y='00um',
    orientation='0',
    ground_gap_x='20um',
    ground_gap_y='5um',
    array_unit=Dict(
            coupling_pad_x='20um',
            coupling_pad_y ='4um',
            coupling_pad_ground_x='100um',
            coupling_pad_ground_y='10um',
            array_pad_x='17.5um',
            array_pad_y='7um',
            array_gap_y='25um',
            array_pad_thickness = '4um',
            n_junction='7',
            )
)

mycell2 = JunctionArray(design, 'myfull2', options=options)

gui.rebuild()
gui.autoscale()

# %%
JunctionArray.get_template_options(design)
# Out:
# {'pos_x': '0.0um',
#  'pos_y': '0.0um',
#  'orientation': '0.0',
#  'chip': 'main',
#  'layer': '1',
#  'ground_gap_x': '20um',
#  'ground_gap_y': '20um',
#  'array_unit': {'array_pad_x': '20um',
#   'array_pad_y': '50um',
#   'array_gap_y': '10um',
#   'junction_thickness': '10um',
#   'n_junction': '10'}}

# %% [markdown]
# ## Render

# %%
#QDesign registers GDS renderer during init of QDesign.
a_gds = design.renderers.gds
# An alternate way to invoke gds commands without using a_gds:
# design.renderers.gds.export_to_gds()

#Show the options for GDS
a_gds.options
# Out:
# {'short_segments_to_not_fillet': 'True',
#  'check_short_segments_by_scaling_fillet': '2.0',
#  'gds_unit': 0.001,
#  'ground_plane': 'True',
#  'negative_mask': {'main': []},
#  'fabricate': 'False',
#  'corners': 'circular bend',
#  'tolerance': '0.00001',
#  'precision': '0.000000001',
#  'width_LineString': '10um',
#  'path_filename': '../resources/Fake_Junctions.GDS',
#  'junction_pad_overlap': '5um',
#  'max_points': '199',
#  'cheese': {'datatype': '100',
#   'shape': '0',
#   'cheese_0_x': '25um',
#   'cheese_0_y': '25um',
#   'cheese_1_radius': '100um',
#   'view_in_file': {'main': {1: True}},
#   'delta_x': '100um',
#   'delta_y': '100um',
#   'edge_nocheese': '200um'},
#  'no_cheese': {'datatype': '99',
#   'buffer': '25um',
#   'cap_style': '2',
#   'join_style': '2',
#   'view_in_file': {'main': {1: True}}},
#  'bounding_box_scale_x': '1.2',
#  'bounding_box_scale_y': '1.2'}

# %%
# View every entry in junction table.
design.qgeometry.tables['junction']
# Out:
#   component       name                                       geometry  layer  \
# 0         1  rect_jj_0  LINESTRING (0.00000 0.00350, 0.00000 0.02850)      1
# 1         1  rect_jj_1  LINESTRING (0.00000 0.03550, 0.00000 0.06050)      1
# 2         1  rect_jj_2  LINESTRING (0.00000 0.06750, 0.00000 0.09250)      1
# 3         1  rect_jj_3  LINESTRING (0.00000 0.09950, 0.00000 0.12450)      1
# 4         1  rect_jj_4  LINESTRING (0.00000 0.13150, 0.00000 0.15650)      1
# 5         1  rect_jj_5  LINESTRING (0.00000 0.16350, 0.00000 0.18850)      1
# 6         1  rect_jj_6  LINESTRING (0.00000 0.19550, 0.00000 0.22050)      1
#
#    subtract  helper  chip  width hfss_inductance  hfss_capacitance  \
# 0     False   False  main   0.01            10nH                 0
# 1     False   False  main   0.01            10nH                 0
# 2     False   False  main   0.01            10nH                 0
# 3     False   False  main   0.01            10nH                 0
# ...

# %%
design.qgeometry.tables['poly']
# Out:
#   component         name                                           geometry  \
# 0         1     jj_pad_0  POLYGON ((0.00875 -0.00350, 0.00875 0.00350, -...
# 1         1     jj_pad_1  POLYGON ((0.00875 0.02850, 0.00875 0.03550, -0...
# 2         1     jj_pad_2  POLYGON ((0.00875 0.06050, 0.00875 0.06750, -0...
# 3         1     jj_pad_3  POLYGON ((0.00875 0.09250, 0.00875 0.09950, -0...
# 4         1     jj_pad_4  POLYGON ((0.00875 0.12450, 0.00875 0.13150, -0...
# 5         1     jj_pad_5  POLYGON ((0.00875 0.15650, 0.00875 0.16350, -0...
# 6         1     jj_pad_6  POLYGON ((0.00875 0.18850, 0.00875 0.19550, -0...
# 7         1     jj_pad_7  POLYGON ((0.00875 0.22050, 0.00875 0.22750, -0...
# 8         1  ground_etch  POLYGON ((0.02875 -0.00850, 0.02875 0.23250, -...
#
#    layer  subtract  helper  chip fillet
# 0      1     False   False  main    NaN
# 1      1     False   False  main    NaN
# 2      1     False   False  main    NaN
# 3      1     False   False  main    NaN
# ...

# %%
a_gds.options['path_filename'] = './Fake_Junctions.GDS'

# %%
a_gds.export_to_gds('array_cell.gds')
# Out:
# 05:40PM 55s WARNING [_import_junctions_to_one_cell]: Not able to find file:"./Fake_Junctions.GDS".  Not used to replace junction. Checked directory:"C:\Users\figenyilmaz\Desktop\qiskit-metal\tutorials_ME\Figen\Fluxonuim\Calibraitions_GDS".
# 1

# %%
# a_gds.options['path_filename'] = './Fake_Junctions.GDS'

# %%
# a_gds.export_to_gds('array_cell.gds')

# %% [markdown]
# ## V2, JJ gds cell name added

# %%
design.delete_all_components()

options=Dict(
    pos_x='-00um',
    pos_y='00um',
    orientation='0',
    ground_gap_x='20um',
    ground_gap_y='5um',
    array_unit=Dict(
            coupling_pad_x='20um',
            coupling_pad_y ='4um',
            coupling_pad_ground_x='100um',
            coupling_pad_ground_y='10um',
            array_pad_x='17.5um',
            array_pad_y='7um',
            array_gap_y='25um',
            array_pad_thickness = '4um',
            n_junction='7',
            )
)

mycell2 = JunctionArray(design, 'myfull2', options=options)

gui.rebuild()
gui.autoscale()

# %%
# View every entry in junction table.
design.qgeometry.tables['junction']
# Out:
#   component       name                                       geometry  layer  \
# 0         2  rect_jj_0  LINESTRING (0.00000 0.00350, 0.00000 0.02850)      1
# 1         2  rect_jj_1  LINESTRING (0.00000 0.03550, 0.00000 0.06050)      1
# 2         2  rect_jj_2  LINESTRING (0.00000 0.06750, 0.00000 0.09250)      1
# 3         2  rect_jj_3  LINESTRING (0.00000 0.09950, 0.00000 0.12450)      1
# 4         2  rect_jj_4  LINESTRING (0.00000 0.13150, 0.00000 0.15650)      1
# 5         2  rect_jj_5  LINESTRING (0.00000 0.16350, 0.00000 0.18850)      1
# 6         2  rect_jj_6  LINESTRING (0.00000 0.19550, 0.00000 0.22050)      1
#
#    subtract  helper  chip  width hfss_inductance  hfss_capacitance  \
# 0     False   False  main   0.01            10nH                 0
# 1     False   False  main   0.01            10nH                 0
# 2     False   False  main   0.01            10nH                 0
# 3     False   False  main   0.01            10nH                 0
# ...

# %%
#QDesign registers GDS renderer during init of QDesign.
a_gds = design.renderers.gds
# An alternate way to invoke gds commands without using a_gds:
# design.renderers.gds.export_to_gds()

#Show the options for GDS
a_gds.options
# Out:
# {'short_segments_to_not_fillet': 'True',
#  'check_short_segments_by_scaling_fillet': '2.0',
#  'gds_unit': 0.001,
#  'ground_plane': 'True',
#  'negative_mask': {'main': []},
#  'fabricate': 'False',
#  'corners': 'circular bend',
#  'tolerance': '0.00001',
#  'precision': '0.000000001',
#  'width_LineString': '10um',
#  'path_filename': './Fake_Junctions.GDS',
#  'junction_pad_overlap': '5um',
#  'max_points': '199',
#  'cheese': {'datatype': '100',
#   'shape': '0',
#   'cheese_0_x': '25um',
#   'cheese_0_y': '25um',
#   'cheese_1_radius': '100um',
#   'view_in_file': {'main': {1: True}},
#   'delta_x': '100um',
#   'delta_y': '100um',
#   'edge_nocheese': '200um'},
#  'no_cheese': {'datatype': '99',
#   'buffer': '25um',
#   'cap_style': '2',
#   'join_style': '2',
#   'view_in_file': {'main': {1: True}}},
#  'bounding_box_scale_x': '1.2',
#  'bounding_box_scale_y': '1.2'}

# %%
a_gds.options['path_filename'] = './Fake_Junctions.GDS'

# %%
a_gds.export_to_gds('array_cell2.gds')
# Out:
# 05:45PM 28s WARNING [_import_junctions_to_one_cell]: Not able to find file:"./Fake_Junctions.GDS".  Not used to replace junction. Checked directory:"C:\Users\figenyilmaz\Desktop\qiskit-metal\tutorials_ME\Figen\Fluxonuim\Calibraitions_GDS".
# 1

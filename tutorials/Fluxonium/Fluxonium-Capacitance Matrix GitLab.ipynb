# %% [markdown]
# # The Capacitance Matrix of Fluxonium Qubits

# %% [markdown]
# ## Sections
# 1. Prepare the layout in qiskit-metal. <br>
# 1. Run finite element LOM analysis. <br>

# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np
from collections import OrderedDict

import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, open_docs
from qiskit_metal.qlibrary.qubits.fluxoniumLOM import FluxoniumPocket

from qiskit_metal.toolbox_metal import math_and_overrides

from qiskit_metal.qlibrary.core import QComponent

from qiskit_metal.renderers.renderer_ansys.ansys_renderer import QAnsysRenderer

# %% [markdown]
# ### Create the Qubit design
#
# Setup a design of a given dimension. Dimensions will be respected in the design rendering. <br>
# Note that the design size extends from the origin into the first quadrant.
#
# Here we have only one of the qubits.

# %%
design = designs.DesignPlanar({}, True)
design.chips.main.material = 'silicon'
design.chips.main.size['size_x'] = '9mm'
design.chips.main.size['size_y'] = '9mm'
design.variables['cpw_width'] = '15 um'
design.variables['cpw_gap'] = '8.733 um'

design.delete_all_components()

hfss = design.renderers.hfss
gui = MetalGUI(design)

# %%
from qiskit_metal.qlibrary.qubits.fluxoniumLOM import FluxoniumPocket

# Q1 details
options = dict(chip='main', pad_gap='30um', orientation='0',
        pad_width='15um', pad_height='120um', pad_radius='75um',  
        l_arm_length='50um', l_arm_width='2um', l_length='80um', l_width='2um',
               
    flux_bias_line_options=Dict(make_fbl = True,
        fbl_sep='150um', fbl_height ='50um'), 
               
    charge_line_options=Dict(loc_H = +1, make_cl = True,
            cl_length = '80um', cl_sep ='10um' ), 
    readout_line_options=Dict(loc_H = -1, make_rol = True, 
            pad_width = '350um', pad_height = '90um',
            pad_sep='65um'))
               
q1 = FluxoniumPocket(design,'Q1', options = dict(
        **options))

gui.rebuild()
#gui.autoscale()
# Out:
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %%
gui.screenshot()

# %% [markdown]
# ## 2. Capacitance Analysis and LOM derivation using the analysis package - most users

# %%
from qiskit_metal.analyses.quantization import LOManalysis
c1 = LOManalysis(design, "q3d")

# %%
# for second method. dont run this
# example: update single setting
c1.sim.setup.max_passes = 15
# example: update multiple settings
c1.sim.setup_update(solution_order = 'Medium', auto_increase_solution_order = 'False')

c1.sim.setup
# Out:
# {'name': 'Setup',
#  'reuse_selected_design': True,
#  'reuse_setup': True,
#  'freq_ghz': 5.0,
#  'save_fields': False,
#  'enabled': True,
#  'max_passes': 15,
#  'min_passes': 2,
#  'min_converged_passes': 2,
#  'percent_error': 0.5,
#  'percent_refinement': 30,
#  'auto_increase_solution_order': 'False',
#  'solution_order': 'Medium',
#  'solver_type': 'Iterative'}

# %%
c1.sim.run(components=['Q1'], open_terminations=[('Q1', 'charge_line'), ('Q1', 'flux_bias_line'), ('Q1', 'fake_flux_bias_line'), ('Q1', 'readout_line')])
c1.sim.capacitance_matrix
# Out:
# INFO 10:12PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 10:12PM [load_ansys_project]: 	Opened Ansys App
# INFO 10:12PM [load_ansys_project]: 	Opened Ansys Desktop v2020.2.0
# INFO 10:12PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    C:/Users/figenyilmaz/Documents/Ansoft/
# 	Project:   Project22
# INFO 10:12PM [connect_design]: No active design found (or error getting active design).
# INFO 10:12PM [connect]: 	 Connected to project "Project22". No design detected
# INFO 10:12PM [connect_design]: 	Opened active design
# 	Design:    Design_q3d [Solution type: Q3D]
# WARNING 10:12PM [connect_setup]: 	No design setup detected.
# WARNING 10:12PM [connect_setup]: 	Creating Q3D default setup.
# INFO 10:12PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 10:12PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 10:12PM [analyze]: Analyzing setup Setup
# INFO 10:16PM [get_matrix]: Exporting matrix data to (C:\Users\FIGENY~1\AppData\Local\Temp\tmp63f__fno.txt, C, , Setup:LastAdaptive, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 1, False
# INFO 10:16PM [get_matrix]: Exporting matrix data to (C:\Users\FIGENY~1\AppData\Local\Temp\tmpnxxtg0co.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 1, False
# INFO 10:16PM [get_matrix]: Exporting matrix data to (C:\Users\FIGENY~1\AppData\Local\Temp\tmpht8pkblz.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 2, False
# INFO 10:16PM [get_matrix]: Exporting matrix data to (C:\Users\FIGENY~1\AppData\Local\Temp\tmpbvm40pz8.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 3, False
# INFO 10:16PM [get_matrix]: Exporting matrix data to (C:\Users\FIGENY~1\AppData\Local\Temp\tmphfnlklhj.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 4, False
# INFO 10:16PM [get_matrix]: Exporting matrix data to (C:\Users\FIGENY~1\AppData\Local\Temp\tmpt7s26n81.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 5, False
# INFO 10:16PM [get_matrix]: Exporting matrix data to (C:\Users\FIGENY~1\AppData\Local\Temp\tmpc4zkbiv2.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 6, False
# INFO 10:16PM [get_matrix]: Exporting matrix data to (C:\Users\FIGENY~1\AppData\Local\Temp\tmpyff8ngb6.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 7, False
# INFO 10:16PM [get_matrix]: Exporting matrix data to (C:\Users\FIGENY~1\AppData\Local\Temp\tmpzg_szg2x.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 8, False
# INFO 10:16PM [get_matrix]: Exporting matrix data to (C:\Users\FIGENY~1\AppData\Local\Temp\tmpna0uf7qa.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 9, False
# INFO 10:16PM [get_matrix]: Exporting matrix data to (C:\Users\FIGENY~1\AppData\Local\Temp\tmpneld8b42.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 10, False
# INFO 10:16PM [get_matrix]: Exporting matrix data to (C:\Users\FIGENY~1\AppData\Local\Temp\tmp6u2p3yvg.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 11, False
#                      charge_line_Q1  flux_bias_line_Q1  ground_main_plane  \
# charge_line_Q1             16.82954           -0.03479          -16.47565
# flux_bias_line_Q1          -0.03479           56.68363          -45.46151
# ground_main_plane         -16.47565          -45.46151          321.61383
# pad_bot_Q1                 -0.03114           -4.43956          -28.65820
# pad_top_Q1                 -0.16174           -4.42990          -31.79645
# readout_padNline_Q1        -0.01295           -1.05059         -129.04626
#
#                      pad_bot_Q1  pad_top_Q1  readout_padNline_Q1
# charge_line_Q1         -0.03114    -0.16174             -0.01295
# flux_bias_line_Q1      -4.43956    -4.42990             -1.05059
# ground_main_plane     -28.65820   -31.79645           -129.04626
# pad_bot_Q1             44.72242    -5.29194             -4.23365
# pad_top_Q1             -5.29194    44.69483             -0.83620
# readout_padNline_Q1    -4.23365    -0.83620            136.57203

# %%
c1.sim.save_screenshot()
# Out:
# WindowsPath('C:/Users/figenyilmaz/Desktop/qiskit-metal/tutorials/Figen/Fluxonuim/ansys.png')

# %%
c1.sim.close()

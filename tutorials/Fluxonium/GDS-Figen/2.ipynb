# %% [markdown]
# # Fluxonium Design with 6 Single Qubits NEW EVEN SIMPLER look
#
# ## GDS file
#
# ### Preparations

# %%
# For convenience, let's begin by enabling
# automatic reloading of modules when they change.
# %load_ext autoreload
# %autoreload 2

import numpy as np
from collections import OrderedDict

import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict
import matplotlib.pyplot as plt

from qiskit_metal.toolbox_metal import math_and_overrides

from qiskit_metal.qlibrary.core import QComponent

from qiskit_metal.qlibrary.tlines.meandered import RouteMeander
from qiskit_metal.qlibrary.tlines.pathfinder import RoutePathfinder
from qiskit_metal.qlibrary.tlines.anchored_path import RouteAnchors

from qiskit_metal.qlibrary.qubits.fluxoniumEPR import FluxoniumPocket

from qiskit_metal.qlibrary.terminations.launchpad_wb import LaunchpadWirebond

from qiskit_metal.qlibrary.terminations.open_to_ground_v2 import OpenToGround

# %%
# Each time you create a new quantum circuit design,
# you start by instantiating a QDesign class.

# The design class `DesignPlanar` is best for 2D circuit designs.
design = designs.DesignPlanar()
design.chips.main.material = 'silicon'
design.variables['cpw_width'] = '15 um'
design.variables['cpw_gap'] = '8.733 um'
design._chips['main']['size']['size_x'] = '20mm'
design._chips['main']['size']['size_y'] = '9mm'

# If you disable the next line with "overwrite_enabled", then you will need to
# delete a component [<component>.delete()] before recreating it.
design.overwrite_enabled = True

gui = MetalGUI(design)

# %%
#Setup the launchpads for the ReadIn and the Readout location and orientation

## Read In launch pad
launch_options = dict(chip='main', pos_x='-4.1mm', pos_y='-3.99mm', orientation='0',
        lead_length='30um', pad_width='150um',
        pad_height='150um', pad_gap='58um',
        taper_height='122um',
                    )
lp = LaunchpadWirebond(design, 'LPReadIn', options = launch_options)


# Read Out launch pad
launch_options = dict(chip='main', pos_x='4.1mm', pos_y='3.99mm', orientation='180',
                      lead_length='30um', pad_width='150um',
        pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPReadOut', options = launch_options)


# Setup the Transmission Line in between ReadIn and Readout pads.
Transmission_Line = {'pin_inputs':
           {'start_pin': {'component': 'LPReadIn', 'pin': 'tie'},
             'end_pin': {'component': 'LPReadOut', 'pin': 'tie'}},
            'lead': {'start_straight': '300um', 'end_straight': '4070um'
                    }, 
                    'total_length': '8mm', 'fillet': "90um"
            }

TransLine = RoutePathfinder(design, 'TL', Transmission_Line)


gui.rebuild()
# Out:
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %%
#For saving time from CR second setup for whole design
#Setup the launchpads for the ReadIn and the Readout location and orientation

## Read In launch pad
launch_options = dict(chip='main', pos_x='6.0mm', pos_y='-3.99mm', orientation='0',
        lead_length='30um', pad_width='150um',
        pad_height='150um', pad_gap='58um',
        taper_height='122um',
                    )
lp2 = LaunchpadWirebond(design, 'LPReadIn2', options = launch_options)


# Read Out launch pad
launch_options = dict(chip='main', pos_x='15.0mm', pos_y='3.99mm', orientation='180',
                      lead_length='30um', pad_width='150um',
        pad_height='150um',
                    )
lp2 = LaunchpadWirebond(design, 'LPReadOut2', options = launch_options)


# Setup the Transmission Line in between ReadIn and Readout pads.
Transmission_Line2 = {'pin_inputs':
           {'start_pin': {'component': 'LPReadIn2', 'pin': 'tie'},
             'end_pin': {'component': 'LPReadOut2', 'pin': 'tie'}},
            'lead': {'start_straight': '300um', 'end_straight': '4070um'
                    }, 
                    'total_length': '8mm', 'fillet': "90um"
            }

TransLine2 = RoutePathfinder(design, 'TL2', Transmission_Line2)


gui.rebuild()
# Out:
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %%
## Q1's flux-bias and charge line
launch_options = dict(chip='main', pos_x='-4.1mm', pos_y='-2.66mm', orientation='0',
                      lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPCL1', options = launch_options)

launch_options = dict(chip='main', pos_x='-4.1mm', pos_y='-1.33mm', orientation='0',
                     lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPFB1', options = launch_options)


## Q2's flux-bias and charge line
launch_options = dict(chip='main', pos_x='-4.1mm', pos_y='0.0mm', orientation='0',
                      lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPCL2', options = launch_options)

launch_options = dict(chip='main', pos_x='-4.1mm', pos_y='+1.33mm', orientation='0',
                      lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPFB2', options = launch_options)


## Q3's flux-bias and charge line
launch_options = dict(chip='main', pos_x='-4.1mm', pos_y='2.66mm', orientation='0',
                      lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPCL3', options = launch_options)

launch_options = dict(chip='main', pos_x='-4.1mm', pos_y='3.99mm', orientation='0',
                      lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPFB3', options = launch_options)


## Q4's flux-bias and charge line
launch_options = dict(chip='main', pos_x='4.1mm', pos_y='2.66mm', orientation='180',
                      lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPFB4', options = launch_options)

launch_options = dict(chip='main', pos_x='4.1mm', pos_y='1.33mm', orientation='180',
                      lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPCL4', options = launch_options)


## Q5's flux-bias and charge line
launch_options = dict(chip='main', pos_x='4.1mm', pos_y='0.0mm', orientation='180',
                      lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPFB5', options = launch_options)

launch_options = dict(chip='main', pos_x='4.1mm', pos_y='-1.33mm', orientation='180',
                      lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPCL5', options = launch_options)


## Q6's flux-bias and charge line
launch_options = dict(chip='main', pos_x='4.1mm', pos_y='-2.66mm', orientation='180',
                      lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPFB6', options = launch_options)

launch_options = dict(chip='main', pos_x='4.1mm', pos_y='-3.99mm', orientation='180',
                      lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPCL6', options = launch_options)


gui.rebuild()
# Out:
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %%
# For the second setup
## Q1-2's flux-bias and charge line
launch_options = dict(chip='main', pos_x='6.0mm', pos_y='-2.66mm', orientation='0',
                      lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPCL1-2', options = launch_options)

launch_options = dict(chip='main', pos_x='6.0mm', pos_y='-1.33mm', orientation='0',
                     lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPFB1-2', options = launch_options)


## Q2-2's flux-bias and charge line
launch_options = dict(chip='main', pos_x='6.0mm', pos_y='0.0mm', orientation='0',
                      lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPCL2-2', options = launch_options)

launch_options = dict(chip='main', pos_x='6.0mm', pos_y='+1.33mm', orientation='0',
                      lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPFB2-2', options = launch_options)


## Q3-2's flux-bias and charge line
launch_options = dict(chip='main', pos_x='6.0mm', pos_y='2.66mm', orientation='0',
                      lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPCL3-2', options = launch_options)

launch_options = dict(chip='main', pos_x='6.0mm', pos_y='3.99mm', orientation='0',
                      lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPFB3-2', options = launch_options)


## Q4-2's flux-bias and charge line
launch_options = dict(chip='main', pos_x='15mm', pos_y='2.66mm', orientation='180',
                      lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPFB4-2', options = launch_options)

launch_options = dict(chip='main', pos_x='15mm', pos_y='1.33mm', orientation='180',
                      lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPCL4-2', options = launch_options)


## Q5-2's flux-bias and charge line
launch_options = dict(chip='main', pos_x='15mm', pos_y='0.0mm', orientation='180',
                      lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPFB5-2', options = launch_options)

launch_options = dict(chip='main', pos_x='15mm', pos_y='-1.33mm', orientation='180',
                      lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPCL5-2', options = launch_options)


## Q6-2's flux-bias and charge line
launch_options = dict(chip='main', pos_x='15mm', pos_y='-2.66mm', orientation='180',
                      lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPFB6-2', options = launch_options)

launch_options = dict(chip='main', pos_x='15mm', pos_y='-3.99mm', orientation='180',
                      lead_length='30um', pad_width='150um', pad_height='150um',
                    )
lp = LaunchpadWirebond(design, 'LPCL6-2', options = launch_options)


gui.rebuild()
# Out:
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %%
from qiskit_metal.qlibrary.qubits.fluxoniumEPR import FluxoniumPocket

gds_cell_name_jj = 'junction_0'
gds_cell_name_inductor = 'jj_chain0'

# Q1 details
options = dict(chip='main', nanowire = False, 
            orientation =90, pos_x = '-2.2mm', pos_y = '-2.3mm',
            gds_cell_name=gds_cell_name_jj,
            gds_cell_inductor=gds_cell_name_inductor ,
               inductor_orientation='-1',
               
    flux_bias_line_options=Dict(make_fbl = True,
                        fbl_sep='150um',), 
               
    charge_line_options=Dict(loc_H = +1, make_cl = True,
            cl_sep ='-10um'),
    readout_line_options=Dict(loc_H = -1, make_rol = True, 
            pad_width = '300um', pad_height = '80um',
            pad_sep='60um', 
              ) )
               
q1 = FluxoniumPocket(design,'Q1', options = dict(
             **options))

# Q6 details
options = dict(chip='main', nanowire = False,
        orientation =90, pos_x = '2.2mm', pos_y = '-3.2mm',
        gds_cell_name=gds_cell_name_jj,
        gds_cell_inductor=gds_cell_name_inductor ,
               inductor_orientation='-1',
               
    flux_bias_line_options=Dict(make_fbl = True,
                        fbl_sep='150um'), 
               
    charge_line_options=Dict(loc_H = -1, make_cl = True,
            cl_sep ='-10um',
                            ), 
    readout_line_options=Dict(loc_H = +1, make_rol = True, 
            pad_width = '300um', pad_height = '80um',
            pad_sep='60um', 
              ) )
               
q6 = FluxoniumPocket(design,'Q6', options = dict(
        **options))


# Q2 details
options = dict(chip='main', nanowire = False,
        orientation =90, pos_x = '-2.2mm', pos_y = '0.2mm',
        gds_cell_name=gds_cell_name_jj,
               gds_cell_inductor=gds_cell_name_inductor ,
               inductor_orientation='-1',
               
    flux_bias_line_options=Dict(make_fbl = True,
                        fbl_sep='150um'), 
               
    charge_line_options=Dict(loc_H = +1, make_cl = True,
            cl_sep ='-10um',
                            ),
    readout_line_options=Dict(loc_H = -1, make_rol = True, 
            pad_width = '300um', pad_height = '80um',
            pad_sep='60um', 
              ) )
               
q2 = FluxoniumPocket(design,'Q2', options = dict(
        **options))

# Q5 details
options = dict(chip='main', nanowire = False,
        orientation =90, pos_x = '2.4mm', pos_y = '-0.8mm',
        gds_cell_name=gds_cell_name_jj,
               gds_cell_inductor=gds_cell_name_inductor ,
               inductor_orientation='-1',
                      
    flux_bias_line_options=Dict(make_fbl = True,
                        fbl_sep='150um'), 
               
    charge_line_options=Dict(loc_H = -1, make_cl = True,
            cl_sep ='-10um',
                            ), 
    readout_line_options=Dict(loc_H = +1, make_rol = True, 
            pad_width = '300um', pad_height = '80um',
            pad_sep='60um', 
              ) )
               
q5 = FluxoniumPocket(design,'Q5', options = dict(
        **options))


# Q3 details
options = dict(chip='main', nanowire = False,
        orientation =90, pos_x = '-2.5mm', pos_y = '3.0mm',
        gds_cell_name=gds_cell_name_jj,
        gds_cell_inductor=gds_cell_name_inductor ,
               inductor_orientation='-1',
               
    flux_bias_line_options=Dict(make_fbl = True,
                        fbl_sep='150um'), 
               
    charge_line_options=Dict(loc_H = +1, make_cl = True,
            cl_sep ='-10um',
                            ),
    readout_line_options=Dict(loc_H = -1, make_rol = True, 
            pad_width = '300um', pad_height = '80um',
            pad_sep='60um', 
              ) )
               
q3 = FluxoniumPocket(design,'Q3', options = dict(
        **options))

# Q4 details
options = dict(chip='main', nanowire = False,
        orientation =90, pos_x = '2.4mm', pos_y = '2.0mm',
        gds_cell_name=gds_cell_name_jj,
        gds_cell_inductor=gds_cell_name_inductor,
               inductor_orientation='-1',
               
    flux_bias_line_options=Dict(make_fbl = True,
                        fbl_sep='150um'), 
               
    charge_line_options=Dict(loc_H = -1, make_cl = True,
            cl_sep ='-10um',
                            ),
    readout_line_options=Dict(loc_H = 1, make_rol = True, 
            pad_width = '300um', pad_height = '80um',
            pad_sep='60um', 
              ) )
               
q4 = FluxoniumPocket(design,'Q4', options = dict(
        **options))

# Q JJ1 Trial details
options = dict(chip='main',  nanowire = False,
        orientation =90, pos_x = '-1.0mm', pos_y = '1.2mm',
        gds_cell_name=gds_cell_name_jj,
               
    flux_bias_line_options=Dict(make_fbl = False), 
               
    charge_line_options=Dict(loc_H = -1, make_cl = False,
                            ),
    readout_line_options=Dict(loc_H = 1, make_rol = False,
              ) )
               
qJJ1 = FluxoniumPocket(design,'QJJ1', options = dict(
        **options))

# Q JJ2 Trial details
options = dict(chip='main', nanowire = False,
        orientation =90, pos_x = '-1.0mm', pos_y = '1.5mm',
        gds_cell_name=gds_cell_name_jj,   
               
    flux_bias_line_options=Dict(make_fbl = False), 
               
    charge_line_options=Dict(loc_H = -1, make_cl = False,
                            ),
    readout_line_options=Dict(loc_H = 1, make_rol = False,
              ) )
               
qJJ2 = FluxoniumPocket(design,'QJJ2', options = dict(
        **options))

# Q JJ3 Trial details
options = dict(chip='main', nanowire = False,
        orientation =90, pos_x = '-1.0mm', pos_y = '1.8mm',
        gds_cell_name=gds_cell_name_jj,  
               
    flux_bias_line_options=Dict(make_fbl = False), 
               
    charge_line_options=Dict(loc_H = -1, make_cl = False,
                            ),
    readout_line_options=Dict(loc_H = 1, make_rol = False,
              ) )
               
qJJ3 = FluxoniumPocket(design,'QJJ3', options = dict(
        **options))


# Q Array1 details
options = dict(chip='main', nanowire = False, 
            orientation =90, pos_x = '1.0mm', pos_y = '0.8mm',
            gds_cell_inductor=gds_cell_name_inductor ,
               inductor_orientation='-1',
               
    flux_bias_line_options=Dict(make_fbl = False,
                        fbl_sep='150um',), 
               
    charge_line_options=Dict(loc_H = +1, make_cl = False,
            cl_sep ='-10um'),
    readout_line_options=Dict(loc_H = -1, make_rol = False, 
            pad_width = '300um', pad_height = '80um',
            pad_sep='60um', 
              ) )
               
qArr1 = FluxoniumPocket(design,'QArr1', options = dict(
             **options))


# Q Array2 Trial details
options = dict(chip='main', nanowire = False,
        orientation =90, pos_x = '1.0mm', pos_y = '1.1mm',
        gds_cell_inductor=gds_cell_name_inductor ,   
               inductor_orientation='-1',
               
    flux_bias_line_options=Dict(make_fbl = False,
                        fbl_sep='150um'), 
               
    charge_line_options=Dict(loc_H = +1, make_cl = False,
            cl_sep ='-10um',
                            ),
    readout_line_options=Dict(loc_H = -1, make_rol = False, 
            pad_width = '300um', pad_height = '80um',
            pad_sep='60um', 
              ) )
               
qArr2 = FluxoniumPocket(design,'QArr2', options = dict(
        **options))

# Q Array3 Trial details
options = dict(chip='main', nanowire = False,
        orientation =90, pos_x = '1.0mm', pos_y = '1.4mm',
        gds_cell_inductor=gds_cell_name_inductor , 
               inductor_orientation='-1',
               
    flux_bias_line_options=Dict(make_fbl = False,
                        fbl_sep='150um'), 
               
    charge_line_options=Dict(loc_H = +1, make_cl = False,
            cl_sep ='-10um',
                            ),
    readout_line_options=Dict(loc_H = -1, make_rol = False, 
            pad_width = '300um', pad_height = '80um',
            pad_sep='60um', 
              ) )
               
qArr3 = FluxoniumPocket(design,'QArr3', options = dict(
        **options))


gui.rebuild()
# Out:
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# ...
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %%
# Lambda/2 resonator for Q1
otg1 = OpenToGround(design, 'otg1s', options=dict(chip='main', 
                 pos_x='-37.733um', pos_y='-2.8mm', orientation='270'))
rt_meander = RouteMeander(design, 'cavity1',  Dict(meander=Dict(spacing='200um'),
        total_length='8.4mm',
        hfss_wire_bonds = True,
        fillet='99um',
        lead = dict(start_straight='250um'),
        pin_inputs=Dict(
            start_pin=Dict(component='otg1s', pin='open'),
            end_pin=Dict(component='Q1', pin='readout_line')), ))

# Lambda/2 resonator for Q6
otg6 = OpenToGround(design, 'otg6s', options=dict(chip='main', pos_x='37.733um',  pos_y='-2.5mm', orientation='90'))
rt_meander = RouteMeander(design, 'cavity6',  Dict(meander=Dict(spacing='200um'),
        total_length='9.0mm',
        hfss_wire_bonds = True,
        fillet='99um',
        lead = dict(start_straight='250um'),
        pin_inputs=Dict(
            start_pin=Dict(component='otg6s', pin='open'),
            end_pin=Dict(component='Q6', pin='readout_line')), ))

# Lambda/2 resonator for Q2
otg2 = OpenToGround(design, 'otg2s', options=dict(chip='main', pos_x='-37.733um',  pos_y='-0.8mm', orientation='270'))
rt_meander = RouteMeander(design, 'cavity2',  Dict(meander=Dict(spacing='200um'),
        total_length='9.6mm',
        hfss_wire_bonds = True,
        fillet='99um',
        lead = dict(start_straight='250um'),
        pin_inputs=Dict(
            start_pin=Dict(component='otg2s', pin='open'),
            end_pin=Dict(component='Q2', pin='readout_line')), ))

# Lambda/2 resonator for Q5
otg5 = OpenToGround(design, 'otg5s', options=dict(chip='main', pos_x='37.733um',  pos_y='-0.5mm', orientation='90'))
rt_meander = RouteMeander(design, 'cavity5',  Dict(meander=Dict(spacing='200um'),
        total_length='10.2mm',
        hfss_wire_bonds = True,
        fillet='99um',
        lead = dict(start_straight='250um'),
        pin_inputs=Dict(
            start_pin=Dict(component='otg5s', pin='open'),
            end_pin=Dict(component='Q5', pin='readout_line')), ))

# Lambda/2 resonator for Q3
otg3 = OpenToGround(design, 'otg3s', options=dict(chip='main', pos_x='-37.733um',  pos_y='3.0mm', orientation='270'))
rt_meander = RouteMeander(design, 'cavity3',  Dict(meander=Dict(spacing='200um'),
        total_length='11.0mm',
        hfss_wire_bonds = True,
        fillet='99um',
        lead = dict(start_straight='250um'),
        pin_inputs=Dict(
            start_pin=Dict(component='otg3s', pin='open'),
            end_pin=Dict(component='Q3', pin='readout_line')), ))

# Lambda/2 resonator for Q4
otg4 = OpenToGround(design, 'otg4s', options=dict(chip='main', pos_x='37.733um',  pos_y='2.8mm', orientation='270'))
rt_meander = RouteMeander(design, 'cavity4',  Dict(meander=Dict(spacing='200um'),
        total_length='11.9mm',
        hfss_wire_bonds = True,
        fillet='99um',
        lead = dict(start_straight='250um'),
        pin_inputs=Dict(
            start_pin=Dict(component='otg4s', pin='open'),
            end_pin=Dict(component='Q4', pin='readout_line')), ))


gui.rebuild()
gui.autoscale()
# Out:
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# ...
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %%
# Second setup
from qiskit_metal.qlibrary.qubits.fluxoniumEPR import FluxoniumPocket

gds_cell_name_jj = 'junction_0'
gds_cell_name_inductor = 'jj_chain0'

# Q1-2 details
options = dict(chip='main', nanowire = False, 
            orientation =90, pos_x = '8.8mm', pos_y = '-2.3mm',
            gds_cell_name=gds_cell_name_jj,
            gds_cell_inductor=gds_cell_name_inductor ,
               inductor_orientation='-1',
               
    flux_bias_line_options=Dict(make_fbl = True,
                        fbl_sep='150um',), 
               
    charge_line_options=Dict(loc_H = +1, make_cl = True,
            cl_sep ='-10um'),
    readout_line_options=Dict(loc_H = -1, make_rol = True, 
            pad_width = '300um', pad_height = '80um',
            pad_sep='60um', 
              ) )
               
q1_2 = FluxoniumPocket(design,'Q1-2', options = dict(
             **options))

# Q6-2 details
options = dict(chip='main', nanowire = False,
        orientation =90, pos_x = '13.0mm', pos_y = '-3.2mm',
        gds_cell_name=gds_cell_name_jj,
        gds_cell_inductor=gds_cell_name_inductor ,
               inductor_orientation='-1',
               
    flux_bias_line_options=Dict(make_fbl = True,
                        fbl_sep='150um'), 
               
    charge_line_options=Dict(loc_H = -1, make_cl = True,
            cl_sep ='-10um',
                            ), 
    readout_line_options=Dict(loc_H = +1, make_rol = True, 
            pad_width = '300um', pad_height = '80um',
            pad_sep='60um', 
              ) )
               
q6_2 = FluxoniumPocket(design,'Q6-2', options = dict(
        **options))


# Q2-2 details
options = dict(chip='main', nanowire = False,
        orientation =90, pos_x = '8.4mm', pos_y = '0.2mm',
        gds_cell_name=gds_cell_name_jj,
               gds_cell_inductor=gds_cell_name_inductor ,
               inductor_orientation='-1',
               
    flux_bias_line_options=Dict(make_fbl = True,
                        fbl_sep='150um'), 
               
    charge_line_options=Dict(loc_H = +1, make_cl = True,
            cl_sep ='-10um',
                            ),
    readout_line_options=Dict(loc_H = -1, make_rol = True, 
            pad_width = '300um', pad_height = '80um',
            pad_sep='60um', 
              ) )
               
q2_2 = FluxoniumPocket(design,'Q2-2', options = dict(
        **options))

# Q5-2 details
options = dict(chip='main', nanowire = False,
        orientation =90, pos_x = '13.2mm', pos_y = '-0.8mm',
        gds_cell_name=gds_cell_name_jj,
               gds_cell_inductor=gds_cell_name_inductor ,
               inductor_orientation='-1',
                      
    flux_bias_line_options=Dict(make_fbl = True,
                        fbl_sep='150um'), 
               
    charge_line_options=Dict(loc_H = -1, make_cl = True,
            cl_sep ='-10um',
                            ), 
    readout_line_options=Dict(loc_H = +1, make_rol = True, 
            pad_width = '300um', pad_height = '80um',
            pad_sep='60um', 
              ) )
               
q5_2 = FluxoniumPocket(design,'Q5-2', options = dict(
        **options))


# Q3-2 details
options = dict(chip='main', nanowire = False,
        orientation =90, pos_x = '8.2mm', pos_y = '3.0mm',
        gds_cell_name=gds_cell_name_jj,
        gds_cell_inductor=gds_cell_name_inductor ,
               inductor_orientation='-1',
               
    flux_bias_line_options=Dict(make_fbl = True,
                        fbl_sep='150um'), 
               
    charge_line_options=Dict(loc_H = +1, make_cl = True,
            cl_sep ='-10um',
                            ),
    readout_line_options=Dict(loc_H = -1, make_rol = True, 
            pad_width = '300um', pad_height = '80um',
            pad_sep='60um', 
              ) )
               
q3_2 = FluxoniumPocket(design,'Q3-2', options = dict(
        **options))

# Q4-2 details
options = dict(chip='main', nanowire = False,
        orientation =90, pos_x = '13.4mm', pos_y = '2.0mm',
        gds_cell_name=gds_cell_name_jj,
        gds_cell_inductor=gds_cell_name_inductor,
               inductor_orientation='-1',
               
    flux_bias_line_options=Dict(make_fbl = True,
                        fbl_sep='150um'), 
               
    charge_line_options=Dict(loc_H = -1, make_cl = True,
            cl_sep ='-10um',
                            ),
    readout_line_options=Dict(loc_H = 1, make_rol = True, 
            pad_width = '300um', pad_height = '80um',
            pad_sep='60um', 
              ) )
               
q4_2 = FluxoniumPocket(design,'Q4-2', options = dict(
        **options))

# Q JJ1-2 Trial details
options = dict(chip='main',  nanowire = False,
        orientation =90, pos_x = '9.8mm', pos_y = '1.2mm',
        gds_cell_name=gds_cell_name_jj,
               
    flux_bias_line_options=Dict(make_fbl = False), 
               
    charge_line_options=Dict(loc_H = -1, make_cl = False,
                            ),
    readout_line_options=Dict(loc_H = 1, make_rol = False,
              ) )
               
qJJ1_2 = FluxoniumPocket(design,'QJJ1-2', options = dict(
        **options))

# Q JJ2-2 Trial details
options = dict(chip='main', nanowire = False,
        orientation =90, pos_x = '9.8mm', pos_y = '1.5mm',
        gds_cell_name=gds_cell_name_jj,   
               
    flux_bias_line_options=Dict(make_fbl = False), 
               
    charge_line_options=Dict(loc_H = -1, make_cl = False,
                            ),
    readout_line_options=Dict(loc_H = 1, make_rol = False,
              ) )
               
qJJ2_2 = FluxoniumPocket(design,'QJJ2-2', options = dict(
        **options))

# Q JJ3-2 Trial details
options = dict(chip='main', nanowire = False,
        orientation =90, pos_x = '9.8mm', pos_y = '1.8mm',
        gds_cell_name=gds_cell_name_jj,  
               
    flux_bias_line_options=Dict(make_fbl = False), 
               
    charge_line_options=Dict(loc_H = -1, make_cl = False,
                            ),
    readout_line_options=Dict(loc_H = 1, make_rol = False,
              ) )
               
qJJ3_2 = FluxoniumPocket(design,'QJJ3-2', options = dict(
        **options))


# Q Array1-2 details
options = dict(chip='main', nanowire = False, 
            orientation =90, pos_x = '12.0mm', pos_y = '0.8mm',
            gds_cell_inductor=gds_cell_name_inductor ,
               inductor_orientation='-1',
               
    flux_bias_line_options=Dict(make_fbl = False,
                        fbl_sep='150um',), 
               
    charge_line_options=Dict(loc_H = +1, make_cl = False,
            cl_sep ='-10um'),
    readout_line_options=Dict(loc_H = -1, make_rol = False, 
            pad_width = '300um', pad_height = '80um',
            pad_sep='60um', 
              ) )
               
qArr1_2 = FluxoniumPocket(design,'QArr1-2', options = dict(
             **options))


# Q Array2-2 Trial details
options = dict(chip='main', nanowire = False,
        orientation =90, pos_x = '12.0mm', pos_y = '1.1mm',
        gds_cell_inductor=gds_cell_name_inductor ,   
               inductor_orientation='-1',
               
    flux_bias_line_options=Dict(make_fbl = False,
                        fbl_sep='150um'), 
               
    charge_line_options=Dict(loc_H = +1, make_cl = False,
            cl_sep ='-10um',
                            ),
    readout_line_options=Dict(loc_H = -1, make_rol = False, 
            pad_width = '300um', pad_height = '80um',
            pad_sep='60um', 
              ) )
               
qArr2_2 = FluxoniumPocket(design,'QArr2-2', options = dict(
        **options))

# Q Array3-2 Trial details
options = dict(chip='main', nanowire = False,
        orientation =90, pos_x = '12.0mm', pos_y = '1.4mm',
        gds_cell_inductor=gds_cell_name_inductor , 
               inductor_orientation='-1',
               
    flux_bias_line_options=Dict(make_fbl = False,
                        fbl_sep='150um'), 
               
    charge_line_options=Dict(loc_H = +1, make_cl = False,
            cl_sep ='-10um',
                            ),
    readout_line_options=Dict(loc_H = -1, make_rol = False, 
            pad_width = '300um', pad_height = '80um',
            pad_sep='60um', 
              ) )
               
qArr3_2 = FluxoniumPocket(design,'QArr3-2', options = dict(
        **options))


gui.rebuild()
# Out:
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# ...
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %%
# setup for second
# Lambda/2 resonator for Q1
otg1_2 = OpenToGround(design, 'otg1s-2', options=dict(chip='main', 
                 pos_x='10.8mm', pos_y='-2.8mm', orientation='270'))
rt_meander = RouteMeander(design, 'cavity1-2',  Dict(meander=Dict(spacing='200um'),
        total_length='8.4mm',
        hfss_wire_bonds = True,
        fillet='99um',
        lead = dict(start_straight='250um'),
        pin_inputs=Dict(
            start_pin=Dict(component='otg1s-2', pin='open'),
            end_pin=Dict(component='Q1-2', pin='readout_line')), ))

# Lambda/2 resonator for Q6-2
otg6_2 = OpenToGround(design, 'otg6s-2', options=dict(chip='main', pos_x='11.0mm',  pos_y='-2.5mm', orientation='90'))
rt_meander = RouteMeander(design, 'cavity6-2',  Dict(meander=Dict(spacing='200um'),
        total_length='9.0mm',
        hfss_wire_bonds = True,
        fillet='99um',
        lead = dict(start_straight='250um'),
        pin_inputs=Dict(
            start_pin=Dict(component='otg6s-2', pin='open'),
            end_pin=Dict(component='Q6-2', pin='readout_line')), ))

# Lambda/2 resonator for Q2-2
otg2_2 = OpenToGround(design, 'otg2s-2', options=dict(chip='main', pos_x='10.8mm',  pos_y='-0.8mm', orientation='270'))
rt_meander = RouteMeander(design, 'cavity2-2',  Dict(meander=Dict(spacing='200um'),
        total_length='9.6mm',
        hfss_wire_bonds = True,
        fillet='99um',
        lead = dict(start_straight='250um'),
        pin_inputs=Dict(
            start_pin=Dict(component='otg2s-2', pin='open'),
            end_pin=Dict(component='Q2-2', pin='readout_line')), ))

# Lambda/2 resonator for Q5-2
otg5_2 = OpenToGround(design, 'otg5s-2', options=dict(chip='main', pos_x='11.0mm',  pos_y='-0.5mm', orientation='90'))
rt_meander = RouteMeander(design, 'cavity5-2',  Dict(meander=Dict(spacing='200um'),
        total_length='10.2mm',
        hfss_wire_bonds = True,
        fillet='99um',
        lead = dict(start_straight='250um'),
        pin_inputs=Dict(
            start_pin=Dict(component='otg5s-2', pin='open'),
            end_pin=Dict(component='Q5-2', pin='readout_line')), ))

# Lambda/2 resonator for Q3-2
otg3_2 = OpenToGround(design, 'otg3s-2', options=dict(chip='main', pos_x='10.8mm',  pos_y='3.0mm', orientation='270'))
rt_meander = RouteMeander(design, 'cavity3-2',  Dict(meander=Dict(spacing='200um'),
        total_length='11.0mm',
        hfss_wire_bonds = True,
        fillet='99um',
        lead = dict(start_straight='250um'),
        pin_inputs=Dict(
            start_pin=Dict(component='otg3s-2', pin='open'),
            end_pin=Dict(component='Q3-2', pin='readout_line')), ))

# Lambda/2 resonator for Q4-2
otg4_2 = OpenToGround(design, 'otg4s-2', options=dict(chip='main', pos_x='11.0mm',  pos_y='2.8mm', orientation='270'))
rt_meander = RouteMeander(design, 'cavity4-2',  Dict(meander=Dict(spacing='200um'),
        total_length='11.9mm',
        hfss_wire_bonds = True,
        fillet='99um',
        lead = dict(start_straight='250um'),
        pin_inputs=Dict(
            start_pin=Dict(component='otg4s-2', pin='open'),
            end_pin=Dict(component='Q4-2', pin='readout_line')), ))


gui.rebuild()
gui.autoscale()
# Out:
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# ...
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %%
# Charge Line and Flux Bias Line for Q1
XYCharge_LineQ1 = RoutePathfinder(design, 'XY_Gate1', 
        options = dict(chip='main', fillet='99um',
            lead=dict(start_straight='150um', end_straight='600um', 
                     ),
            pin_inputs=Dict(start_pin=Dict(component='Q1', pin='charge_line'),
                            end_pin=Dict(component='LPCL1', pin='tie')
                                            )))

ZFluxBias_LineQ1 = RoutePathfinder(design, 'Z_Gate1', 
        options = dict(chip='main', fillet='99um',
            lead=dict(start_straight='200um', 
        end_straight='400um'),
        pin_inputs=Dict(start_pin=Dict(component='Q1', 
              pin='flux_bias_line'),
          end_pin=Dict(component='LPFB1', pin='tie')
                                   )))

# Charge Lıne and Flux Bias Line for Q2
XYCharge_LineQ2 = RoutePathfinder(design, 'XY_Gate2', options = dict(chip='main',
                        fillet='80um',
                lead=dict(start_straight='150um', end_straight='850um'),
                pin_inputs=Dict(start_pin=Dict(component='Q2', pin='charge_line'),
                                    end_pin=Dict(component='LPCL2',pin='tie')
   
                               )))
ZFluxBias_LineQ2 = RoutePathfinder(design, 'Z_Gate2', options = dict(chip='main',
             fillet='99um',
          lead=dict(start_straight='250um', end_straight='250um'),
        pin_inputs=Dict(start_pin=Dict(component='Q2', pin='flux_bias_line'),
                            end_pin=Dict(component='LPFB2',pin='tie')
                                            )))

# Charge Lıne and Flux Bias Line for Q3
XYCharge_LineQ3 = RoutePathfinder(design, 'XY_Gate3', options = dict(chip='main',
                         fillet='99um',
       lead=dict(start_straight='250um', end_straight='200um'), 
            pin_inputs=Dict(start_pin=Dict(component='Q3', pin='charge_line'),
                    end_pin=Dict(component='LPCL3', pin='tie')
                                            )))

ZFluxBias_LineQ3 = RoutePathfinder(design, 'Z_Gate3', options = dict(chip='main',
                fillet='99um',
           lead=dict(start_straight='100um', end_straight='200um'),
            pin_inputs=Dict(start_pin=Dict(component='Q3', pin='flux_bias_line'),
                end_pin=Dict(component='LPFB3', pin='tie')
                                            )))

# Charge Lıne and Flux Bias Line for Q6
XYCharge_LineQ6 = RoutePathfinder(design, 'XY_Gate6', 
        options = dict(chip='main', fillet='99um',
        lead=dict(start_straight='100um', end_straight='250um'),
    pin_inputs=Dict(start_pin=Dict(component='Q6', pin='charge_line'),
    end_pin=Dict(component='LPCL6', pin='tie')
                                            )))

ZFluxBias_LineQ6 = RoutePathfinder(design, 'Z_Gate6', 
        options = dict(chip='main', fillet='99um',
            lead=dict(start_straight='350um', end_straight='350um'),
        pin_inputs=Dict(start_pin=Dict(component='Q6', 
              pin='flux_bias_line'),
          end_pin=Dict(component='LPFB6', pin='tie')
                                   )))

# Charge Lıne and Flux Bias Line for Q5
XYCharge_LineQ5 = RoutePathfinder(design, 'XY_Gate5', options = dict(chip='main',
                          fillet='99um',
            lead=dict(start_straight='150um', end_straight='850um'),
                    pin_inputs=Dict(start_pin=Dict(component='Q5',pin='charge_line'),
                    end_pin=Dict(component='LPCL5', pin='tie')
                                            )))
ZFluxBias_LineQ5 = RoutePathfinder(design, 'Z_Gate5', options = dict(chip='main',
                        fillet='99um',
            lead=dict(start_straight='200um', end_straight='450um'),
                pin_inputs=Dict(start_pin=Dict(component='Q5', pin='flux_bias_line'),
                            end_pin=Dict(component='LPFB5', pin='tie')
                                            )))

# Charge Line and Flux Bias Line for Q4
XYCharge_LineQ4 = RoutePathfinder(design, 'XY_Gate4', options = dict(chip='main',
                    fillet='99um',
                    lead=dict(start_straight='200um', end_straight='550um'),pin_inputs=Dict(
                        start_pin=Dict(component='Q4', pin='charge_line'),
                            end_pin=Dict(component='LPCL4', pin='tie')
                                            )))

ZFluxBias_LineQ4 = RoutePathfinder(design, 'Z_Gate4', options = dict(chip='main',
                            fillet='99um',
                    lead=dict(start_straight='150um', end_straight='200um'), pin_inputs=Dict(
                            start_pin=Dict(component='Q4',
                                pin='flux_bias_line'),
                                end_pin=Dict(component='LPFB4',
                                        pin='tie')
                                            )))


gui.rebuild()
# Out:
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qlibrary\tlines\anchored_path.py:164: ShapelyDeprecationWarning: The 'cascaded_union()' function is deprecated. Use 'unary_union()' instead.
#   boundary = gpd.GeoSeries(cascaded_union(polygons + paths_converted))
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# ...
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %%
# Charge Line and Flux Bias Line for Q1
XYCharge_LineQ1 = RoutePathfinder(design, 'XY_Gate1-2', 
        options = dict(chip='main', fillet='99um',
            lead=dict(start_straight='150um', end_straight='600um', 
                     ),
            pin_inputs=Dict(start_pin=Dict(component='Q1-2', pin='charge_line'),
                            end_pin=Dict(component='LPCL1-2', pin='tie')
                                            )))

ZFluxBias_LineQ1 = RoutePathfinder(design, 'Z_Gate1-2', 
        options = dict(chip='main', fillet='99um',
            lead=dict(start_straight='200um', 
        end_straight='400um'),
        pin_inputs=Dict(start_pin=Dict(component='Q1-2', 
              pin='flux_bias_line'),
          end_pin=Dict(component='LPFB1-2', pin='tie')
                                   )))

# Charge Lıne and Flux Bias Line for Q2
XYCharge_LineQ2 = RoutePathfinder(design, 'XY_Gate2-2', options = dict(chip='main',
                        fillet='80um',
                lead=dict(start_straight='150um', end_straight='850um'),
                pin_inputs=Dict(start_pin=Dict(component='Q2-2', pin='charge_line'),
                                    end_pin=Dict(component='LPCL2-2',pin='tie')
   
                               )))
ZFluxBias_LineQ2 = RoutePathfinder(design, 'Z_Gate2-2', options = dict(chip='main',
             fillet='99um',
          lead=dict(start_straight='250um', end_straight='250um'),
        pin_inputs=Dict(start_pin=Dict(component='Q2-2', pin='flux_bias_line'),
                            end_pin=Dict(component='LPFB2-2',pin='tie')
                                            )))

# Charge Lıne and Flux Bias Line for Q3
XYCharge_LineQ3 = RoutePathfinder(design, 'XY_Gate3-2', options = dict(chip='main',
                         fillet='99um',
       lead=dict(start_straight='250um', end_straight='200um'), 
            pin_inputs=Dict(start_pin=Dict(component='Q3-2', pin='charge_line'),
                    end_pin=Dict(component='LPCL3-2', pin='tie')
                                            )))

ZFluxBias_LineQ3 = RoutePathfinder(design, 'Z_Gate3-2', options = dict(chip='main',
                fillet='99um',
           lead=dict(start_straight='100um', end_straight='200um'),
            pin_inputs=Dict(start_pin=Dict(component='Q3-2', pin='flux_bias_line'),
                end_pin=Dict(component='LPFB3-2', pin='tie')
                                            )))

# Charge Lıne and Flux Bias Line for Q6
XYCharge_LineQ6 = RoutePathfinder(design, 'XY_Gate6-2', 
        options = dict(chip='main', fillet='99um',
        lead=dict(start_straight='100um', end_straight='250um'),
    pin_inputs=Dict(start_pin=Dict(component='Q6-2', pin='charge_line'),
    end_pin=Dict(component='LPCL6-2', pin='tie')
                                            )))

ZFluxBias_LineQ6 = RoutePathfinder(design, 'Z_Gate6-2', 
        options = dict(chip='main', fillet='99um',
            lead=dict(start_straight='350um', end_straight='350um'),
        pin_inputs=Dict(start_pin=Dict(component='Q6-2', 
              pin='flux_bias_line'),
          end_pin=Dict(component='LPFB6-2', pin='tie')
                                   )))

# Charge Lıne and Flux Bias Line for Q5
XYCharge_LineQ5 = RoutePathfinder(design, 'XY_Gate5-2', options = dict(chip='main',
                          fillet='99um',
            lead=dict(start_straight='150um', end_straight='850um'),
                    pin_inputs=Dict(start_pin=Dict(component='Q5-2',pin='charge_line'),
                    end_pin=Dict(component='LPCL5-2', pin='tie')
                                            )))
ZFluxBias_LineQ5 = RoutePathfinder(design, 'Z_Gate5-2', options = dict(chip='main',
                        fillet='99um',
            lead=dict(start_straight='200um', end_straight='450um'),
                pin_inputs=Dict(start_pin=Dict(component='Q5-2', pin='flux_bias_line'),
                            end_pin=Dict(component='LPFB5-2', pin='tie')
                                            )))

# Charge Line and Flux Bias Line for Q4
XYCharge_LineQ4 = RoutePathfinder(design, 'XY_Gate4-2', options = dict(chip='main',
                    fillet='99um',
                    lead=dict(start_straight='200um', end_straight='550um'),pin_inputs=Dict(
                        start_pin=Dict(component='Q4-2', pin='charge_line'),
                            end_pin=Dict(component='LPCL4-2', pin='tie')
                                            )))

ZFluxBias_LineQ4 = RoutePathfinder(design, 'Z_Gate4-2', options = dict(chip='main',
                            fillet='99um',
                    lead=dict(start_straight='150um', end_straight='200um'), pin_inputs=Dict(
                            start_pin=Dict(component='Q4-2',
                                pin='flux_bias_line'),
                                end_pin=Dict(component='LPFB4-2',
                                        pin='tie')
                                            )))


gui.rebuild()
# Out:
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qlibrary\tlines\anchored_path.py:164: ShapelyDeprecationWarning: The 'cascaded_union()' function is deprecated. Use 'unary_union()' instead.
#   boundary = gpd.GeoSeries(cascaded_union(polygons + paths_converted))
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qlibrary\tlines\anchored_path.py:164: ShapelyDeprecationWarning: The 'cascaded_union()' function is deprecated. Use 'unary_union()' instead.
#   boundary = gpd.GeoSeries(cascaded_union(polygons + paths_converted))
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qlibrary\tlines\anchored_path.py:164: ShapelyDeprecationWarning: The 'cascaded_union()' function is deprecated. Use 'unary_union()' instead.
#   boundary = gpd.GeoSeries(cascaded_union(polygons + paths_converted))
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qlibrary\tlines\anchored_path.py:164: ShapelyDeprecationWarning: The 'cascaded_union()' function is deprecated. Use 'unary_union()' instead.
#   boundary = gpd.GeoSeries(cascaded_union(polygons + paths_converted))
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qlibrary\tlines\anchored_path.py:164: ShapelyDeprecationWarning: The 'cascaded_union()' function is deprecated. Use 'unary_union()' instead.
#   boundary = gpd.GeoSeries(cascaded_union(polygons + paths_converted))
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qlibrary\tlines\anchored_path.py:164: ShapelyDeprecationWarning: The 'cascaded_union()' function is deprecated. Use 'unary_union()' instead.
#   boundary = gpd.GeoSeries(cascaded_union(polygons + paths_converted))
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# ...
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qlibrary\tlines\anchored_path.py:164: ShapelyDeprecationWarning: The 'cascaded_union()' function is deprecated. Use 'unary_union()' instead.
#   boundary = gpd.GeoSeries(cascaded_union(polygons + paths_converted))
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qlibrary\tlines\anchored_path.py:164: ShapelyDeprecationWarning: The 'cascaded_union()' function is deprecated. Use 'unary_union()' instead.
#   boundary = gpd.GeoSeries(cascaded_union(polygons + paths_converted))
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qlibrary\tlines\anchored_path.py:164: ShapelyDeprecationWarning: The 'cascaded_union()' function is deprecated. Use 'unary_union()' instead.
#   boundary = gpd.GeoSeries(cascaded_union(polygons + paths_converted))
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qlibrary\tlines\anchored_path.py:164: ShapelyDeprecationWarning: The 'cascaded_union()' function is deprecated. Use 'unary_union()' instead.
#   boundary = gpd.GeoSeries(cascaded_union(polygons + paths_converted))
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\designs\net_info.py:135: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._net_info = self._net_info.append(temp_df, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\shapely\geometry\base.py:250: ShapelyDeprecationWarning: Setting the 'coords' to mutate a Geometry in place is deprecated, and will not be possible any more in Shapely 2.0
#   super().__setattr__(name, value)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\qgeometries\qgeometries_handler.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.tables[kind] = table.append(df, sort=False, ignore_index=True)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
#
# WARNING:py.warnings:C:\Users\figenyilmaz\Anaconda3\envs\qiskit-metal\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %%
#Save screenshot as a .png formatted file.
gui.screenshot()

# %%
q1 #print Q1 information

# %%
gui.main_window.close()

# %% [markdown]
# ## GDS

# %%
fluxonium_gds = design.renderers.gds
fluxonium_gds.options
# Out:
# {'short_segments_to_not_fillet': 'True',
#  'check_short_segments_by_scaling_fillet': '2.0',
#  'gds_unit': 0.001,
#  'ground_plane': 'True',
#  'negative_mask': {'main': []},
#  'fabricate': 'False',
#  'corners': 'circular bend',
#  'tolerance': '0.00001',
#  'precision': '0.000000001',
#  'width_LineString': '10um',
#  'path_filename': '../resources/Fake_Junctions.GDS',
#  'junction_pad_overlap': '5um',
#  'max_points': '199',
#  'cheese': {'datatype': '100',
#   'shape': '0',
#   'cheese_0_x': '25um',
#   'cheese_0_y': '25um',
#   'cheese_1_radius': '200um',
#   'view_in_file': {'main': {1: True}},
#   'delta_x': '100um',
#   'delta_y': '100um',
#   'edge_nocheese': '300um'},
#  'no_cheese': {'datatype': '99',
#   'buffer': '25um',
#   'cap_style': '2',
#   'join_style': '2',
#   'view_in_file': {'main': {1: True}}},
#  'bounding_box_scale_x': '1.2',
#  'bounding_box_scale_y': '1.2'}

# %%
fluxonium_gds.options['path_filename'] = 'Fluxonium_JJandArray.gds'

# %%
fluxonium_gds.options['fabricate'] = True

# %%
fluxonium_gds.export_to_gds('FluxoniumPocket-Single6Q-460nmArray100nmJJTwins.gds')
# Out:
# 03:43AM 31s WARNING [_give_rotation_center_twopads]: In junction table, component=Q1 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 03:43AM 31s WARNING [_give_rotation_center_twopads]: In junction table, component=Q6 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 03:43AM 31s WARNING [_give_rotation_center_twopads]: In junction table, component=Q2 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 03:43AM 31s WARNING [_give_rotation_center_twopads]: In junction table, component=Q5 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 03:43AM 31s WARNING [_give_rotation_center_twopads]: In junction table, component=Q3 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 03:43AM 31s WARNING [_give_rotation_center_twopads]: In junction table, component=Q4 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 03:43AM 31s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "gds_cell_inductor"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 03:43AM 31s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "gds_cell_inductor"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 03:43AM 31s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "gds_cell_inductor"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 03:43AM 31s WARNING [_give_rotation_center_twopads]: In junction table, component=QArr1 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 03:43AM 31s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "my_other_junction"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 03:43AM 31s WARNING [_give_rotation_center_twopads]: In junction table, component=QArr2 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 03:43AM 31s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "my_other_junction"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 03:43AM 31s WARNING [_give_rotation_center_twopads]: In junction table, component=QArr3 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 03:43AM 31s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "my_other_junction"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 03:43AM 31s WARNING [_give_rotation_center_twopads]: In junction table, component=Q1-2 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 03:43AM 31s WARNING [_give_rotation_center_twopads]: In junction table, component=Q6-2 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 03:43AM 31s WARNING [_give_rotation_center_twopads]: In junction table, component=Q2-2 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 03:43AM 31s WARNING [_give_rotation_center_twopads]: In junction table, component=Q5-2 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 03:43AM 31s WARNING [_give_rotation_center_twopads]: In junction table, component=Q3-2 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 03:43AM 31s WARNING [_give_rotation_center_twopads]: In junction table, component=Q4-2 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 03:43AM 31s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "gds_cell_inductor"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 03:43AM 31s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "gds_cell_inductor"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 03:43AM 31s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "gds_cell_inductor"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 03:43AM 31s WARNING [_give_rotation_center_twopads]: In junction table, component=QArr1-2 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 03:43AM 31s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "my_other_junction"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 03:43AM 31s WARNING [_give_rotation_center_twopads]: In junction table, component=QArr2-2 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 03:43AM 31s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "my_other_junction"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 03:43AM 31s WARNING [_give_rotation_center_twopads]: In junction table, component=QArr3-2 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 03:43AM 31s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "my_other_junction"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 03:43AM 31s WARNING [_cheese_buffer_maker]: The bounding box for no-cheese is outside of chip size.
# Bounding box for chip is (-10.0, -4.5, 10.0, 4.5).
# Bounding box with no_cheese buffer is (-4.455, -4.148000000000001, 15.355, 4.148000000000001).
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\renderers\renderer_gds\gds_renderer.py:2172: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   all_polys = list(multi_poly)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\renderers\renderer_gds\gds_renderer.py:2172: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   all_polys = list(multi_poly)
# 1

# %%
fluxonium_gds.options['max_points'] = '8191'

# %%
fluxonium_gds.export_to_gds('FluxoniumPocket-Single6Q-460nmArray100nmJJTwins8191.gds')
# Out:
# 04:29AM 20s WARNING [_give_rotation_center_twopads]: In junction table, component=Q1 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 04:29AM 20s WARNING [_give_rotation_center_twopads]: In junction table, component=Q6 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 04:29AM 20s WARNING [_give_rotation_center_twopads]: In junction table, component=Q2 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 04:29AM 20s WARNING [_give_rotation_center_twopads]: In junction table, component=Q5 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 04:29AM 20s WARNING [_give_rotation_center_twopads]: In junction table, component=Q3 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 04:29AM 20s WARNING [_give_rotation_center_twopads]: In junction table, component=Q4 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 04:29AM 20s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "gds_cell_inductor"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 04:29AM 20s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "gds_cell_inductor"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 04:29AM 20s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "gds_cell_inductor"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 04:29AM 20s WARNING [_give_rotation_center_twopads]: In junction table, component=QArr1 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 04:29AM 20s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "my_other_junction"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 04:29AM 20s WARNING [_give_rotation_center_twopads]: In junction table, component=QArr2 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 04:29AM 20s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "my_other_junction"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 04:29AM 20s WARNING [_give_rotation_center_twopads]: In junction table, component=QArr3 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 04:29AM 20s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "my_other_junction"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 04:29AM 20s WARNING [_give_rotation_center_twopads]: In junction table, component=Q1-2 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 04:29AM 20s WARNING [_give_rotation_center_twopads]: In junction table, component=Q6-2 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 04:29AM 20s WARNING [_give_rotation_center_twopads]: In junction table, component=Q2-2 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 04:29AM 20s WARNING [_give_rotation_center_twopads]: In junction table, component=Q5-2 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 04:29AM 20s WARNING [_give_rotation_center_twopads]: In junction table, component=Q3-2 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 04:29AM 20s WARNING [_give_rotation_center_twopads]: In junction table, component=Q4-2 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 04:29AM 20s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "gds_cell_inductor"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 04:29AM 20s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "gds_cell_inductor"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 04:29AM 20s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "gds_cell_inductor"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 04:29AM 20s WARNING [_give_rotation_center_twopads]: In junction table, component=QArr1-2 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 04:29AM 20s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "my_other_junction"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 04:29AM 20s WARNING [_give_rotation_center_twopads]: In junction table, component=QArr2-2 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 04:29AM 20s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "my_other_junction"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 04:29AM 20s WARNING [_give_rotation_center_twopads]: In junction table, component=QArr3-2 with name=inductor has width=0.001 smaller than cell dimension=0.013.
# 04:29AM 20s WARNING [_import_junctions_to_one_cell]: From the "junction" table, the cell named "my_other_junction"",  is not in file: Fluxonium_JJandArray.gds. The cell was not used.
# 04:29AM 20s WARNING [_cheese_buffer_maker]: The bounding box for no-cheese is outside of chip size.
# Bounding box for chip is (-10.0, -4.5, 10.0, 4.5).
# Bounding box with no_cheese buffer is (-4.455, -4.148000000000001, 15.355, 4.148000000000001).
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\renderers\renderer_gds\gds_renderer.py:2172: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   all_polys = list(multi_poly)
#
# WARNING:py.warnings:c:\users\figenyilmaz\documents\github\qiskit-metal\qiskit_metal\renderers\renderer_gds\gds_renderer.py:2172: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   all_polys = list(multi_poly)
# 1

# %%
# View every entry in junction table.
design.qgeometry.tables['junction']

# %%
fluxonium_gds.options
